# %% [markdown]
# <a href="https://colab.research.google.com/github/jiki007/OS_project/blob/main/reflection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 💡 Reflection
#
# This assignment gave us hands-on experience with Ubuntu automation by
# implementing five distinct real-world scenarios. Through the Package Manager
# simulator, we learned how Linux resolves dependencies automatically — a core
# OS concept that happens silently every time we install software. The Smart Home
# scenario demonstrated how operating systems respond to real-time data through
# event-driven automation, mirroring how Ubuntu handles hardware interrupts.
# Building the File Organization system deepened our understanding of how Ubuntu
# manages its file system, directory structure, and file operations programmatically.
# The Cron Job Scheduler showed us how Linux handles process scheduling without
# human intervention — a fundamental OS concept used in every production server.
# Finally, the Chatbot scenario demonstrated how shell commands can be integrated
# into intelligent applications using Python's subprocess module, bridging the gap
# between user interaction and OS-level commands. Overall, this assignment connected
# theoretical OS concepts to practical Ubuntu automation, showing us how operating
# systems silently manage and automate tasks that we take for granted in daily computing.
